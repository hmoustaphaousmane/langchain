# %% [markdown]
# # LangChain: Q&A over Documents

# %%
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# %%
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from langchain.document_loaders import CSVLoader
from langchain.vectorstores import DocArrayInMemorySearch  # Deprecated
# from langchain_openai import DocArrayInMemorySearch
from IPython.display import display, Markdown
from langchain.llms import OpenAI

# %%
file = 'l4_outdoor_clothing_catalog_1000.csv'
loader = CSVLoader(file_path=file)  # Initialize a csv loader

# %%
# Install sqlalchemy: required in order to import VectorstoreIndexCreator
# %pip install --upgrade --force-reinstall sqlalchemy

# %%
# Import an index
from langchain.indexes import VectorstoreIndexCreator

# %%
# Install DocArray
# %pip install docarray

# %%
index = VectorstoreIndexCreator(
    vectorstore_cls=DocArrayInMemorySearch
).from_loaders([loader])
# Out:
# /home/hassane/anaconda3/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.0.9 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %%
query = "Please list all your shirt with sun protection in a table in markdown and summarize each one"

# %%
response = index.query(query)

# %%
display(Markdown(response))
# Out:
# | Name | Description | Sun Protection Rating |
# | --- | --- | --- |
# | Men's Tropical Plaid Short-Sleeve Shirt | Made of 100% polyester, UPF 50+ rating, wrinkle-resistant, front and back cape venting, two front bellows pockets | SPF 50+ |
# | Men's Plaid Tropic Shirt, Short-Sleeve | Made of 52% polyester and 48% nylon, UPF 50+ rating, SunSmart technology, wrinkle-free, front and back cape venting, two front bellows pockets | SPF 50+ |
# | Sun Shield Shirt | Made of 78% nylon and 22% Lycra Xtra Life fiber, UPF 50+ rating, moisture-wicking, abrasion-resistant, fits over swimsuit | SPF 50+ |
# | Men's TropicVibe Shirt, Short-Sleeve | Made of 71% nylon and 29% polyester, UPF 50+ rating, wrinkle-resistant, front and back cape venting, two front bellows pockets | SPF 50+ |
#
# Each of these shirts offers UPF 50+ sun protection, blocking 98% of the sun's harmful rays. They are all made of

# %% [markdown]
# ## Step By Step

# %%
from langchain.document_loaders import CSVLoader

# Create Document loader
loader = CSVLoader(file_path=file)

# %%
# Load document
docs = loader.load()

# %%
docs[0]
# Out:
# Document(page_content=": 0\nname: Women's Campside Oxfords\ndescription: This ultracomfortable lace-to-toe Oxford boasts a super-soft canvas, thick cushioning, and quality construction for a broken-in feel from the first time you put them on. \n\nSize & Fit: Order regular shoe size. For half sizes not offered, order up to next whole size. \n\nSpecs: Approx. weight: 1 lb.1 oz. per pair. \n\nConstruction: Soft canvas material for a broken-in feel and look. Comfortable EVA innersole with Cleansport NXT® antimicrobial odor control. Vintage hunt, fish and camping motif on innersole. Moderate arch contour of innersole. EVA foam midsole for cushioning and support. Chain-tread-inspired molded rubber outsole with modified chain-tread pattern. Imported. \n\nQuestions? Please contact us for any inquiries.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 0})

# %%
# Create embeddings using OpenAI's embedding class
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

# %%
embed = embeddings.embed_query("Hi my name is Hassane")

# %%
print(len(embed))
# Out:
# 1536

# %%
print(embed[:5])
# Out:
# [-0.019437601216748666, 0.01022392294959846, -0.018631964372620626, -0.023453000241461477, -0.005351734655516281]

# %%
len(docs)
# Out:
# 1000

# %%
docs_750 = docs[:750]
# Out:
# [Document(page_content=": 0\nname: Women's Campside Oxfords\ndescription: This ultracomfortable lace-to-toe Oxford boasts a super-soft canvas, thick cushioning, and quality construction for a broken-in feel from the first time you put them on. \n\nSize & Fit: Order regular shoe size. For half sizes not offered, order up to next whole size. \n\nSpecs: Approx. weight: 1 lb.1 oz. per pair. \n\nConstruction: Soft canvas material for a broken-in feel and look. Comfortable EVA innersole with Cleansport NXT® antimicrobial odor control. Vintage hunt, fish and camping motif on innersole. Moderate arch contour of innersole. EVA foam midsole for cushioning and support. Chain-tread-inspired molded rubber outsole with modified chain-tread pattern. Imported. \n\nQuestions? Please contact us for any inquiries.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 0}),
#  Document(page_content=': 1\nname: Recycled Waterhog Dog Mat, Chevron Weave\ndescription: Protect your floors from spills and splashing with our ultradurable recycled Waterhog dog mat made right here in the USA. \n\nSpecs\nSmall - Dimensions: 18" x 28". \nMedium - Dimensions: 22.5" x 34.5".\n\nWhy We Love It\nMother nature, wet shoes and muddy paws have met their match with our Recycled Waterhog mats. Ruggedly constructed from recycled plastic materials, these ultratough mats help keep dirt and water off your floors and plastic out of landfills, trails and oceans. Now, that\'s a win-win for everyone.\n\nFabric & Care\nVacuum or hose clean.\n\nConstruction\n24 oz. polyester fabric made from 94% recycled materials.\nRubber backing.\n\nAdditional Features\nFeatures an -exclusive design.\nFeatures thick and thin fibers for scraping dirt and absorbing water.\nDries quickly and resists fading, rotting, mildew and shedding.\nUse indoors or out.\nMade in the USA.\n\nHave questions? Reach out to our customer service team with any questions you may have.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 1}),
#  Document(page_content=": 2\nname: Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece\ndescription: She'll love the bright colors, ruffles and exclusive whimsical prints of this toddler's two-piece swimsuit! Our four-way-stretch and chlorine-resistant fabric keeps its shape and resists snags. The UPF 50+ rated fabric provides the highest rated sun protection possible, blocking 98% of the sun's harmful rays. The crossover no-slip straps and fully lined bottom ensure a secure fit and maximum coverage. Machine wash and line dry for best results. Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 2}),
#  Document(page_content=": 3\nname: Refresh Swimwear, V-Neck Tankini Contrasts\ndescription: Whether you're going for a swim or heading out on an SUP, this watersport-ready tankini top is designed to move with you and stay comfortable. All while looking great in an eye-catching colorblock style. \n\nSize & Fit\nFitted: Sits close to the body.\n\nWhy We Love It\nNot only does this swimtop feel good to wear, its fabric is good for the earth too. In recycled nylon, with Lycra® spandex for the perfect amount of stretch. \n\nFabric & Care\nThe premium Italian-blend is breathable, quick drying and abrasion resistant. \nBody in 82% recycled nylon with 18% Lycra® spandex. \nLined in 90% recycled nylon with 10% Lycra® spandex. \nUPF 50+ rated – the highest rated sun protection possible. \nHandwash, line dry.\n\nAdditional Features\nLightweight racerback straps are easy to get on and off, and won't get in your way. \nFlattering V-neck silhouette. \nImported.\n\nSun Protection That Won't Wear Off\nOur high-performance fabric provides SPF", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 3}),
#  Document(page_content=": 4\nname: EcoFlex 3L Storm Pants\ndescription: Our new TEK O2 technology makes our four-season waterproof pants even more breathable. It's guaranteed to keep you dry and comfortable – whatever the activity and whatever the weather. Size & Fit: Slightly Fitted through hip and thigh. \n\nWhy We Love It: Our state-of-the-art TEK O2 technology offers the most breathability we've ever tested. Great as ski pants, they're ideal for a variety of outdoor activities year-round. Plus, they're loaded with features outdoor enthusiasts appreciate, including weather-blocking gaiters and handy side zips. Air In. Water Out. See how our air-permeable TEK O2 technology keeps you dry and comfortable. \n\nFabric & Care: 100% nylon, exclusive of trim. Machine wash and dry. \n\nAdditional Features: Three-layer shell delivers waterproof protection. Brand new TEK O2 technology provides enhanced breathability. Interior gaiters keep out rain and snow. Full side zips for easy on/off over boots. Two zippered hand pockets. Thigh pocket. Imported.\n\n – Official Supplier to the U.S. Ski Team\nTHEIR WILL", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 4}),
#  Document(page_content=": 5\nname: Smooth Comfort Check Shirt, Slightly Fitted\ndescription: Our men's slightly fitted check shirt is the perfect choice for your wardrobe! Customers love how it fits right out of the dryer. Size & Fit: Slightly Fitted, Relaxed through the chest and sleeve with a slightly slimmer waist. Fabric & Care: 100% cotton poplin, with wrinkle-free performance that won't wash out. Our innovative TrueCool® fabric wicks moisture away from your skin and helps it dry quickly. Additional Features: Traditional styling with a button-down collar and a single patch pocket. Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 5}),
#  Document(page_content=': 6\nname: Mens Outdoor Research Apex Gloves\ndescription: These Outdoor Research Arete gloves are perfect for your backcountry adventures. They feature a tough Taslan nylon shell and removable Gore-Tex® nylon fleece liner that is quick-drying and provides complete protection and warmth. The stretchy nylon Lycra elastane soft-shell fabric on the back of the hands allows for freedom of movement, while the ergonomic design lets your hands move naturally for maximum comfort. The gauntlet closure seals out snow and cold wind, and a special pocket allows for a heat pack to be inserted to help keep your hands warm. Both the shell and 100-weight-fleece liner can be worn alone or together for maximum warmth. Imported. These gloves also offer serious waterproof protection from the elements, and are highly breathable to allow moisture vapor to escape. Get the durability you expect from Gore-Tex fabrics.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 6}),
#  Document(page_content=": 7\nname: Women's Ultraplush Sweats, Relaxed Crewneck\ndescription: This crewneck sweatshirt is crafted from soft french terry, making it feel great after a long day. It also looks so good it could be worn around town. Our most generous fit sits farthest from the body and falls at the hip. It's made of 95% cotton and 5% spandex and is a substantial midweight french terry fabric, smooth on the outside and softly looped on the inside. It's designed with shaping for a flattering, feminine fit and features raglan sleeves, a straight hem with side slits, and a curved hem that's slightly longer in the back. Machine wash and dry. Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 7}),
#  Document(page_content=': 8\nname: Mountain Man Fleece Jacket\ndescription: Our best-value fleece jacket is designed with inspiration from our archives and made from 100% recycled polyester for unbeatable comfort and wear-anywhere style. \n\nSize & Fit: Slightly Fitted. Best with lightweight layer. Falls at hip. \n\nWhy We Love It: Our designers took inspiration from the  archives to create this ultrasoft fleece jacket. We love how the heritage styling is updated with a modern, slimming fit. Plus, it’s made from 100% recycled fleece – so you can stay warm and feel good about it. \n\nFabric & Care: 100% recycled fleece is soft, cozy and gentle on the planet. Ultraplush fibers resist wind for even more warmth. Machine wash and dry. \n\nAdditional Features: Features our classic Mount Katahdin logo. Bart Boot lace-inspired zippers and drawcord. Two lower zippered hand pockets. Elastic cuffs and drawcord hem seal out cold air. Imported.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 8}),
#  Document(page_content=': 9\nname: Compact Camping Table, 25"\ndescription: This aluminum portable camp table is perfect for car camping trips, picnics and tailgates. It features a one-piece design with telescoping legs that folds down into a small package. The table is made from lightweight yet durable aluminum and can hold up to 60 lb. The open dimensions are 25"H x 25"W x 27.5"D and the folded dimensions are 25"H x 24"W x 2"D, and the weight is 5 lb. 10 oz. This table can accommodate dinner for up to four people or can be used as a side table.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 9}),
#  Document(page_content=": 10\nname: Cozy Comfort Pullover Set, Stripe\ndescription: Perfect for lounging, this striped knit set lives up to its name. We used ultrasoft fabric and an easy design that's as comfortable at bedtime as it is when we have to make a quick run out.\n\nSize & Fit\n- Pants are Favorite Fit: Sits lower on the waist.\n- Relaxed Fit: Our most generous fit sits farthest from the body.\n\nFabric & Care\n- In the softest blend of 63% polyester, 35% rayon and 2% spandex.\n\nAdditional Features\n- Relaxed fit top with raglan sleeves and rounded hem.\n- Pull-on pants have a wide elastic waistband and drawstring, side pockets and a modern slim leg.\n\nImported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 10}),
#  Document(page_content=': 11\nname: Ultra-Lofty 850 Stretch Down Hooded Jacket\ndescription: This technical stretch down jacket from our DownTek collection is sure to keep you warm and comfortable with its full-stretch construction providing exceptional range of motion. With a slightly fitted style that falls at the hip and best with a midweight layer, this jacket is suitable for light activity up to 20° and moderate activity up to -30°. The soft and durable 100% polyester shell offers complete windproof protection and is insulated with warm, lofty goose down. Other features include welded baffles for a no-stitch construction and excellent stretch, an adjustable hood, an interior media port and mesh stash pocket and a hem drawcord. Machine wash and dry. Imported.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 11}),
#  Document(page_content=': 12\nname: CozyCloud Flannel Sheet Set\ndescription: Our Ultrasoft Flannel Bedding solid colored soft flannel sheet set is the perfect choice for those looking for year-round comfort. With its five-ounce weight and brushed cotton flannel construction, it will keep its bright colors wash after wash. It has been tested for harmful substances to the STANDARD 100 by OEKO-TEX® Certification (137 CITEVE) and is woven in Portugal exclusively for . This set includes one flat sheet, one fitted sheet and two cases; Twin has one case. \n\nSpecs:\nTwin: \nFlat: 102" x 72".\nFitted: 76" x 39" x 15" pocket depth.\nPillowcases (1): 32" x 20".\n\nFull: \nFlat: 102" x 86".\nFitted: 76" x 54" x 15" pocket depth.\nPillowcases (2): 32" x 20".\n\nQueen: \nFlat: 104" x 96".\nFitted: 80" x 60" x 15" pocket depth.\nPillowcases (2): 32" x 20".\n\nKing: \nFlat: 110', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 12}),
#  Document(page_content=": 13\nname: Men's Maine Explorer Zip-Front Jac-Shirt\ndescription: This classic wool jac-shirt is a unique combination of a jacket and a shirt, so you can wear it all year round. It fits loosely, perfect for layering when it's cold outside but can also be worn as an outer shirt when it's warm. \n\nSize & Fit\nTraditional Fit: Relaxed through the chest, sleeve and waist.\n\nFabric & Care\n85% wool, 15% nylon. \nSolid colors: 11 oz. per sq. yd. \nCamouflage: 15 oz. per sq. yd. \nDry clean. \n\nAdditional Features\nAttached exterior wool cape for additional warmth and protection in drizzle and snow. \nTwo welted handwarmer pockets and two button-through chest pockets. \nCut full for layering in colder weather. \nTop-quality wool for exceptional durability. \nWarm when wet and quiet in the woods. \nUltrasuede trim on cuffs and collar for comfort against skin. \nRugged brass zipper. \nPocket buttons are reinforced for security. \nTwo buttons on cuffs for increased adjustability. \nImported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 13}),
#  Document(page_content=": 14\nname: Easy-Care Classic Stripe Short-Sleeve Shirt, Traditional Fit\ndescription: The ultimate striped chambray shirt – we kept everything you love and made it even better. Light and breathable in 100% cotton, with an easy-care finish that sheds wrinkles remarkably well. \n\nSize & Fit\nTraditional Fit: Relaxed through the chest, sleeve and waist. \n\nWhy We Love It\nEven when something is loved as much as a classic chambray, there's always something you can do to make it even better. And that's just what we did – introducing our exclusive easy-care chambray. It's light, breathable and sheds wrinkles. Just throw it in the wash, and it's ready to wear right out of the dryer. \n\nFabric & Care\n100% cotton chambray. A light iron gives it an even crisper look. Machine wash and dry. \n\nAdditional Features\nSingle patch pocket. Button-down collar. Imported. \n\nQuestions?\nFeel free to contact us with any questions or inquiries.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 14}),
#  Document(page_content=': 15\nname: Wind Chaser 110 Kayak\ndescription: This lightweight recreational kayak is designed with a hard-chined hull for superior performance, a generously sized cockpit for easy entry and exit, and excellent stability so everyone in the family will enjoy paddling it. \n\nSpecs: \nCapacity: 278 lb. \nWeight: 38 lb. with seat; 32 lb. without seat. \nDimensions: 11\' x 27". \n\nConstruction: \nMade from superlight, durable thermoformed ABS plastic. \n\nAdditional Features: \nStern bulkhead provides flotation and dry storage. \n10-inch hinge hatch allows easy access to stern storage compartment. \nBow and stern deck bungee for dry bag and gear storage. \nPaddle holder secures paddle to deck. \nSuper-comfortable frame seat easily clips into a mounted bracket under the deck. \nSeat can be removed for use as a beach chair. \nTwist-loc foot brace system easily adjusts from a seated position. \nMolded grab handles at bow and stern offer a comfortable grip for carrying. \n55-inch XL cockpit allows easy entry/exit and accommodates a small child or pet. \nUSA.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 15}),
#  Document(page_content=": 16\nname: Camo Trekker Midweight Quarter-Zip Pullover Hoodie\ndescription: This camo quarter-zip hoodie is an extremely versatile mid layer that's great for all hunting seasons. It's made from warm, breathable fleece and features an innovative lightweight hood with a built-in face mask. \n\nFabric & Care: 100% polyester. Machine wash and dry.\n\nAdditional Features: An excellent layering piece for cold weather. Wind-resistant hard-shell fleece is quiet and resists water, debris and snags. Super-soft fleece interior is warm and can be worn over layers or next-to-skin. Unique lightweight hood has a built in face mask for extra warmth and total concealment. Built-in articulation allows excellent range of motion. Quarter-length zipper allows for easy on/off and ventilation. Single vertical upper chest storage pocket. Thumbholes in cuff allow extra coverage; they stay closed when not in use. Flat seams won't chafe or catch on under layers. Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 16}),
#  Document(page_content=': 17\nname: Summit Soft Loveseat\ndescription: Our upholstered loveseat sofa is designed for smaller spaces – and years of enjoyment. Specs: Dimensions: 38"H x 61"W x 36"D. Weight: 115 lb. \n\nWhy We Love It: We worked closely with expert upholstery craftsmen in North Carolina to bring you this sturdy classic-styled loveseat at a comfortable price. Our well-designed Pine Point Upholstered Collection features soft yet durable fabric in an enduring traditional style to suit any space. \n\nFabric & Care: 100% polyester fabric. Spot clean. \n\nConstruction: Kiln dried hardwood and manufactured wood. Heavy-gauge steel springs provide extra support. High-density foam and soft polyester fiberfill. \n\nAdditional Features: Comes fully upholstered in a choice of colors for timeless appeal. Designed with plush cushioning in a versatile classic style. USA, fabric imported. \n\nQuestions? Please contact our customer service team for more information.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 17}),
#  Document(page_content=': 18\nname: Zen Wave SUP Board, 10\'8"\ndescription: This inflatable SUP combines the rigidity of a hard board with the convenience of an inflatable. Inflates to a rock-hard 20 psi for performance that rivals a hard board. Specs: Dimensions: 10\'8"L x 35"W x 6"D.\n\nAdditional Features:\n- Appropriate for touring, fitness paddling and light river running.\n- Inflates up to a rock-hard 20 psi for performance that is close to a hard board.\n- Streamlined construction for lightweight performance.\n- Four D-rings for attaching gear and essentials.\n- Includes three fins, travel carry bag, pump and a repair kit.\n- Folds up compactly when deflated for easy transport and storage.\n- EVA Deck Pad provides textured surface for grip and comfort.\n- Imported.\n\nHow to Choose a SUP: Find the best paddleboard for you – from paddling on calm waters to tackling big waves. WATCH THE VIDEO SUP BUYING GUIDE', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 18}),
#  Document(page_content=': 19\nname: Buckingham Leather Sofa\ndescription: Our American-made Leather Lodge Collection offers quality craftsmanship, maximum comfort and casual style. Specs: Dimensions: 36"H x 78"W x 39"D. Weight: 159 lb. 11 oz. (Includes shipping materials). Construction: Durable, solid kiln-dried hardwood frames. High-density foam cushions. Solid wood feet. Rich, top-grain leather has a burnished warmth and a supple feel. Additional Features: Stylish, comfortable and well-built. Frames have exceptional joinery and feature spring construction to ensure resiliency. Chocolate Brown has a supple, broken-in feeling and a beautiful natural patina. Chestnut Brown is slightly distressed for a gorgeous vintage look. Made in USA of imported materials. Questions?', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 19}),
#  Document(page_content=': 20\nname: Women\'s Camelbak Horizon Hydration Pack\ndescription: When it’s time to log some miles, this women’s Aurora CamelBak hydration pack is designed to fit your form, keeping you comfortably hydrated from start to finish. Specs: Pack Capacity: 305 cu. in., 5 L; Weight: 14 oz.; Dimensions: 15 1/8"H x 10¼"W x 8 7/8"D; Hydration capacity: 85 oz. Why We Love It: Designed for women, with a curved harness and a compact shape, it provides the water and gear you need – when and where you need it. Construction: Made from 200-denier plain weave polyester; Ventilated-mesh back panel and harness are light and cool; Antimicrobial lining prevents bad odors and tastes; New Crux reservoir flows 20% faster. Additional Features: Slim design won’t interfere with helmet or jersey pocket access; Curved harness and compact shape fits women’s torsos naturally; Two zip pockets hold keys, spare tubes and other essentials; Reflective piping for visibility; Tab on back for attaching blinking light; Imported.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 20}),
#  Document(page_content=': 21\nname: Militia Pullover, Crewneck\ndescription: Our Men’s commando sweater is comfortable, warm and impeccably styled. Size & Fit: Slightly Fitted: Relaxed through the chest and sleeve, with a slightly slimmer waist. Formerly known as Trim Fit, our Slightly Fitted Sweaters are relaxed through the chest and sleeves and have a slightly slimmer waist. Why We Love It: Steeped in tradition and history, the iconic commando sweater worn in World War II by the British S.A.S. is the inspiration for this sweater. Fabric & Care: 100% merino lambswool, 21 oz. Shoulder and elbow patches: 100% cotton. Handwash and dry flat, or dry clean. Additional Features: Warm wool sweater like those worn by the British Commandos in World War II. Excellent resiliency and shape retention. Crew neck and turn-back cuffs. Elbow and shoulder patches ensure long wear. Well-loved customer favorite. Neat, trim appearance. Nonbinding fit for outdoor comfort. Imported.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 21}),
#  Document(page_content=': 22\nname: Comfyside Sweats, Straight-Leg\ndescription: Our Ultrasoft Sweatpants in a straight-leg style—made from remarkably comfortable french terry. \n\nSize & Fit\nInseams: Misses’ 30½", Petite 28½", Medium Tall 32½", Women\'s 30½". \nClassic Fit: Sits at the waist. \nSlightly fitted through hip and thigh. \nStraight-leg. \n\nFabric & Care\nIn 95% cotton and 5% spandex. \nMachine wash and dry. \n\nAdditional Features\nFrench terry feels wonderfully soft and comfortable next to your skin. \nDesigned with shaping for a more flattering, feminine fit. \nElastic waist with drawstring, front pockets. \nImported. \n\nQuestions? Contact customer service for more information.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 22}),
#  Document(page_content=': 23\nname: Campers\' Adventure Bag, Zip-Top with Shoulder Strap\ndescription: Ideal for waterfowling, dog training or shooting, the water-resistant zip-top tote stands up to rugged use in the field while keeping your belongings protected and dry. It\'s been updated with a convenient shoulder strap. \n\nSpecs\nMedium\nCapacity: Approx. 936 cu. in., 15 L.\nWeight: 1 lb. 1 oz.\nDimensions: 12"H x 13"W x 6"D.\n\nLarge\nCapacity: Approx. 1,785 cu. in., 29 L.\nWeight: 1 lb. 9 oz.\nDimensions: 15"H x 17"W x 7"D.\n\nExtra-Large\nCapacity: Approx. 3,230 cu. in., 53 L.\nWeight: 2 lb 3 oz.\nDimensions: 17"H x 19"W x 10"D.\n\nConstruction\nThermoplastic interior coating that\'s both durable and water resistant to keep your gear dry.\nMade from a tough 1,200-denier polyester shell.\nOverlapped seams double-stitched with nylon won\'t rot or break.\nAdjustable carry shoulder strap made from rugged nylon webbing', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 23}),
#  Document(page_content=": 24\nname: Junior All-Terrain Adventurers\ndescription: Our colorful kids' waterproof hiking shoes feature exclusive Tek2.5 technology and sneaker-like comfort, for fun on and off the trail. Why We Love It: Our hiking boots have a bright design that young hikers will love to wear – and the fun look goes easily from the trail to school. The great fit and rugged construction of these boots earn high marks with our customers, year after year. Construction: Breathable mesh nylon and water-resistant suede upper. Nylex lining. Additional Features: Cushioned EVA midsole and removable EVA footbed provide noticeable comfort, right out of the box. Heel and toe bumpers add durability. Lace-up style for a custom fit. TEK2.5 waterproofing ensures feet will stay dry in all conditions. Trail Trac rubber outsole features a versatile lug pattern for traction on a variety of surfaces. Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 24}),
#  Document(page_content=": 25\nname: Women's PrimaLoft Downpour Jacket\ndescription: Our PrimaLoft hooded insulated jacket is redesigned to keep you warm and lightweight in any weather. It is wind and water resistant and offers two levels of comfort: light activity to 35° and moderate activity to -15°. The updated construction is made with PrimaLoft’s Cross Core technology, which is a fusion of PrimaLoft Gold insulation and Aerogel. This combination provides 15% more warmth without any additional weight. The polyester shell and lining is 100% recycled and machine washable. This jacket features an easy on/off elastic hood, an internal media pocket with audio port, two handpockets, one chest pocket, drawcord hem, and a take-along pocket for easy storage. Explore Cross Core and watch the video for more information.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 25}),
#  Document(page_content=": 26\nname: MaxGrip Sport Socks, Twin Pack\ndescription: Our women's moisture-wicking socks are designed with quick-drying, breathable fabric and thoughtful cushioning to keep your feet cool and dry during any activity. Fabric & Care: 43% nylon, 40% CoolMax polyester, 15% NanoGlide nylon, 2% spandex. Machine wash and dry for best care. Additional Features: CoolMax yarn offers advanced moisture control, NanoGlide technology reduces friction and prevents blisters, mesh surrounds the foot for 360 degrees of breathability, cushioned heels and toes. Fabric imported from USA.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 26}),
#  Document(page_content=': 27\nname: Doggy Den Pad\ndescription: Keep your dog comfortable on the go with our dog kennel pad that features a water-resistant polyester cover and a 2" foam that insulates from the cold kennel floor. Specs: Intermediate: Dimensions: 17" x 26". Large: Dimensions: 18" x 30". Extra-Large: Dimensions: 22" x 33". Construction: Polyester cover and foam. Imported. If you have any questions, please contact us.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 27}),
#  Document(page_content=": 28\nname: Performance Plus Woven Shirt\ndescription: Perfect for trail or travel, this breathable summer shirt has the look and feel of cotton - but is packed with performance. Size & Fit Slightly Fitted: Softly shapes the body. Falls at hip. \n\nWhy We Love It Designed for total versatility in the backcountry or city streets. We made this woven top with a special quick-dry fabric – one of the fastest drying you'll find anywhere, so you can hit the trail or town in a top that looks great and performs even better. \n\nFabric & Care 100% nylon. UPF 40+ rated to block the sun's UV rays. Machine wash and dry. \n\nAdditional Features Dries in less than fourteen minutes. Wicks away moisture. Abrasion-resistant for exceptional durability. Imported. \n\nSun Protection That Won't Wear Off Our high-performance fabric provides SPF 50+ sun protection, blocking 98% of the sun's harmful rays.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 28}),
#  Document(page_content=': 29\nname: Classic Book Pack\ndescription: Our Original Book Pack has been beloved by parents of young students for the past nearly 30 years. Its classic styling and durability are renowned, and now it has been updated with a convenient water bottle pocket. \n\nSpecs:\nCapacity: 1,404 cu. in., 23 liters \nWeight: 1 lb. \nDimensions: 16"H x 13"W x 7¼" \n\nWhy We Love It:\nThis backpack has been a staple for nearly three decades, and its lasting quality is undeniable. Its updated water bottle pocket makes it even more useful for your child\'s everyday needs. \n\nConstruction: \nMade of weatherproof, 100% nylon \nPadded back panel for all-day comfort \nPadded, reinforced shoulder straps \nTough zippers for years of use \n3M™ Scotchlite™ Reflective Material on front and straps for high visibility \n\nAdditional Features:\nLarge main compartment holds a lunch box, books, worksheets, art projects and more \nFront pockets feature a key clip, an organizer panel and a place for lunch money or small treasures \nEasily folds down for stowing in a larger pack or duffle', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 29}),
#  Document(page_content=": 30\nname: Kids' Mountain Adventure Fleece, Print\ndescription: We designed this warm, versatile fleece from anti-pill fabric to continue looking great even after multiple wears – and washings. Size & Fit: Relaxed Fit. Fabric & Care: 100% polyester. Machine wash and dry. Additional Features: High-quality fleece fabric resists pilling for long-lasting good looks. Great on its own or as an extra layer in cooler weather. Stand-up collar, chin guard and zip pockets. 3M™ Scotchlite™ Reflective Material back triangle for increased visibility. Heritage-inspired Mount Katahdin logo. Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 30}),
#  Document(page_content=': 31\nname: Rustic Reclaimed Wood Accent Table\ndescription: This rustic wooden side table with pullout drawer is a unique and space-saving addition to any living area. Handcrafted from white pine, it features a durable low-sheen topcoat and is sanded, stained and finished to create a one-of-a-kind piece. The table measures 24"H x 15"W x 24"D and weighs 26 lb. Made in the USA. Questions? Reach out to us for help.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 31}),
#  Document(page_content=": 32\nname: Timeless Leather Ranger Mocs\ndescription: has been crafting authentic handsewn moccasins of the highest quality since 1936 – and the craftsmanship and comfort of these heritage mocs are no exception. \n\nWhy We Love It: Our premium ranger mocs follow in a decades long tradition of the very best craftsmanship. So strong, durable and timeless, you'll wear them for years (even decades) to come. \n\nConstruction: \n-Comes with rawhide and taslan laces. \n-Full-grain leather upper. \n-Leather pull loop at back collar. \n-Smooth leather lining for comfort with or without socks. \n-Molded rubber outsole. \n-Imported, components USA and imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 32}),
#  Document(page_content=': 33\nname: ed\n\nRangeley Camp Performance Checked Flannel Shirt\ndescription: This flannel shirt jac is made for the adventurous type. Rugged and packed with performance features, it is sure to keep you warm and comfortable no matter where your journey takes you. With a slightly fitted silhouette that softly shapes the body and falls at the low hip, this ultrarugged performance flannel shirt is the perfect combination of soft and substantial. Crafted with a blend of 70% cotton and 30% polyester, high-performance hollow-core polyester yarns are designed to wick away moisture and dry fast. Abrasion-resistant construction ensures it will stand up to wear and tear. Additional features include reinforced elbows and side-seam pockets. Machine wash and dry for easy care. Imported.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 33}),
#  Document(page_content=': 34\nname: Men\'s Camo Traverse Rubber Hunting Boots\ndescription: Warm, waterproof, odor fighting, durable, ultracomfortable and with great traction, these insulated rubber hunting boots stand out from any other rubber boots on the market. They\'re also lighter than most rubber boots. Light activity: to 20°  Moderate activity: to -30° about comfort ratings. \n\nSpecs: Height: 16". Approx. Weight: 4 lb. 8 oz. per pair.\n\nConstruction: Lightweight, rugged vulcanized rubber shell resists punctures and won\'t restrict your movement. 2 mm neoprene with 200 gram PrimaLoft insulation for excellent warmth. Aero-foam under innersole for further protection from cold air and ground. Breathable grid fleece lining helps keep feet dry. Anti-odor treatment keeps foot odor from spooking game. Cushioned innersole for all-day walking. Neoprene top of boot allows full motion. Nylon shank for great support. Mossy Oak Country camo to keep you concealed. Aggressive tread provides great traction yet won\'t hold mud. Imported.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 34}),
#  Document(page_content=': 35\nname: Polar Plunge Tube\ndescription: This tube is designed for commercial tubing parks and is built for years of heavy-duty use. It has a semirigid polyethylene base that slides exceptionally well, even in temperatures as low as -40°F. The cover and inner tube are made of 1,000 denier Cordura nylon top and heavy-duty butyl rubber respectively. Nylon webbing handles and a built-in tow strap make it easy to carry.\n\nRegular: \nDimensions: 34" outside diam. x 10"H. \nWeight: 10 lb.\n\nExtra-Large: \nDimensions: 40" outside diam. x 12"H. \nWeight: 17 lb.\n\nDesigned for: Ages 5 and up or adult/tandem sledding.\n\nVideo: Inflation Instructions\n\nAdditional Features: \nSturdy base coasts on packed or powdered snow. \nRugged shell helps protect inner tube from punctures and abrasion. \nFor solo sledding, we recommend the regular size for smaller children. \nSturdy handles and built-in tow strap make it easy to carry and pull back up the hill. \nImported.\n\nPrintable Instructions (', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 35}),
#  Document(page_content=': 36\nname: Garmin MiniTrack Satellite Communicator\ndescription: The Garmin inReachMini is a palm-sized satellite communicator that lets you send and receive text messages, track and share your journey and, if necessary, trigger an SOS alert to contact the GEOS 24/7 emergency response team. It has dimensions of 3.90”H x 2.04”W x 1.03”W and weighs 3.5 oz. It has a display size of 0.9" x 0.9" with a resolution of 128 x 128 pixels. It is powered by a rechargeable lithium-ion battery with a water rating of IPX7, able to withstand immersion in water up to 1 meter for up to 30 minutes. It has a battery life of up to 90 hours at 10-minute tracking; up to 35 hours at 10-minute tracking with 1-second logging; up to 24 days at 30-minute tracking power save mode; and up to 1 year when powered off. \n\nWhy We Love It:\nAlways be connected with family and friends with the Garmin inReach Mini Satellite Communicator. It is 100% waterproof with 100% global Iridium satellite coverage allowing two-way text messaging from anywhere in the world (subscription required). Trigger an SOS alert and', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 36}),
#  Document(page_content=': 37\nname: Fjord Fleece Sweater\ndescription: Inspired by the traditional sweaters of Norway – worn as a defense against the bone-chilling conditions at sea – this sweater is made of premium 100% wool that will keep you warm wherever you are. Why We Love It: While imitations are endless, it’s hard to find authentic sweaters like these anywhere else, especially at this price. Competitors use wool-blend yarns, more modern machinery and take other measures that just can’t compensate for the tried-and-true craftsmanship of our heirloom sweaters. Made exclusively for us the old-fashioned way, each sweater is expertly knit in Norway by family-run businesses who’ve been making them for generations. Fabric & Care: Premium 100% wool. Handwash and dry flat, or dry clean. Construction: Heavyweight wool is warm enough for unusual cold, whether braving the sea or a New England winter. Additional Features: Time-honored craftsmanship, featuring designs and traditions that go back for generations. Norwegian villagers traditionally knit distinct patterns or cables into the sweaters for good luck. Made in Norway.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 37}),
#  Document(page_content=": 38\nname: Women's Luxurious Shearling-Lined Slides\ndescription: Pamper your soles with these easy-on women's Wicked Good slide slippers, made from authentic shearling and available in jewel tones. Size & Fit - Half sizes order up. \n\nWhy We Love Them - With over 4 million pairs sold over the last 5 years, it’s clear customers think our Wicked Good Slippers deserve the title of Best Slippers Ever Made. They make such a great gift that we sell a pair every 7 seconds during our peak in December. Why are they so popular? There are a few reasons but at the top of the list is the most cozy shearling you can find. Throw in superior construction using premium sheepskin and you’ll know why in Maine, “Wicked Good” is as good as it gets. \n\nFabric & Care - Spot clean. \n\nConstruction - Sheepskin suede upper. Genuine lambswool shearling lining wicks moisture. Durable outsole for added traction. EVA foam footbed. Imported (fur Australia).", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 38}),
#  Document(page_content=": 39\nname: Sealed Leather Moc\ndescription: Whoever said “they don’t build things like they used to” doesn’t own the  Boot. In an easy-to-slip-on, weather-resistant rubber moc style, this pair is handcrafted in Maine with the attention to detail we've insisted on for over 100 years. \n\nSize & Fit\n- With light- or midweight socks: Whole sizes, order 1 size down. Half sizes, order 1½ sizes down. \n- With heavyweight socks: Whole sizes, order your normal size. Half sizes, order the next size down. \n\nWhy We Love Them\nAn avid outdoorsman, Bartholomew Barnstormer wanted to create a comfortable, dry pair of boots for tromping through the backwoods of Maine. Today, our Signature Collection rubber mocs are still sewn right here in Maine, one pair at a time, from rugged, weather-resistant waxed canvas that gets even better with age.\n\nVideo: One Minute on  Boot Care\n\nConstruction\n- Crafted from rugged, weather-resistant waxed canvas. \n- Still made here in Maine from the highest quality materials.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 39}),
#  Document(page_content=': 40\nname: Kork-Ease Myrna Comfort Sandals\ndescription: These platform wedge sandals from Kork-Ease have been beautifully crafted since 1953 for exceptional comfort and timeless style. Constructed from full-grain leather, they feature an adjustable buckle, cushioned footbed, and a cork wedge. Imported. If you have any questions, please contact us.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 40}),
#  Document(page_content=": 41\nname: Men's Trail Model 4 All-Terrain Waterproof Hiking Shoes\ndescription: The comfort of sneakers combined with the protection and support of hiking boots make this shoe an ideal choice for casual wear as well as outdoor adventures. Weighing in at around 2 lb. 5 oz., these shoes feature our exclusive VertiGrip outsole with pronounced multidirectional lugs for excellent traction. The breathable TEK2.5 barrier keeps your feet dry, while the suede and fabric upper, cushioned EVA midsole and removable footbed offer noticeable comfort, right out of the box. Heel-and-toe bumpers add durability. Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 41}),
#  Document(page_content=': 42\nname: Big Agnes Big House 4 Deluxe Tent Ground Cover\ndescription: Protect your tent floor from rocks, debris, and pitch with this footprint. Designed specifically for the Big Agnes Big House 4 Deluxe tent, this ultralight footprint attaches directly to the poles for easy setup. It is made from polyester with 1500mm waterproof polyurethane coating to protect your tent floor from abrasion or punctures. It weighs 15 oz and is imported.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 42}),
#  Document(page_content=': 43\nname: New Balance Women\'s 990v4 Trail Runners\ndescription: The latest in New Balance\'s Made in the USA series, these lightweight road-running shoes combine cushioning and stability designed especially for the moderate-to-high-mileage runner. \n\nSize & Fit: We recommend ordering a half size up or your regular New Balance size. Approx. weight: 1 lb. 7 oz. per pair. Drop: ½".\n\nMade right here in New England, the New Balance 990v4 delivers improved performance and a cool, retro look every runner will appreciate. This latest-generation 990-series running shoe is more breathable than ever, and features a lace keeper to keep the tongue comfortably in place while you rack up the miles.\n\nConstruction: Pigskin-and-mesh upper is rugged, breathable and lightweight. Special ENCAP midsole technology provides support, cushioning and stability. Long-lasting blown rubber outsole. Breathable fabric lining. Soft tongue and dual-density foam collar. Removable foam insole. Made in the USA.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 43}),
#  Document(page_content=": 44\nname: Women's New Balance 608 Leather Cross Comfort Shoes\ndescription: Thanks to their signature fit, natural construction and advanced cushioning, these all-around women‘s leather New Balance sneakers will help you keep moving in comfort. \n\nSize & Fit\nYou should order New Balance active footwear one half size larger than your usual shoe size or your regular New Balance size. Fit best with midweight socks. \n\nSpecs\nApprox. Weight: 1 lb 3 oz. per pair.\n\nConstruction\nGenuine leather upper looks polished yet sporty. EVA midsole ensures long wear. Abzorb technology in the heel and forefoot provides shock absorption. Dual-density collar foam protects your heels and ankles from rubbing. Nonmarking outsole allows for wear on a variety of surfaces. Flex grooves in sole increase flexibility for more natural range of movement. Soft, breathable textile lining. Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 44}),
#  Document(page_content=": 45\nname: Women's Oboz Sawtooth Trekking Shoes\ndescription: These Oboz Sawtooth hiking shoes are the perfect combination of an athletic profile and heavy-duty tread, making them suitable for a walk in the park or tackling the most challenging trails. The ventilated design offers breathability and comfort in warm weather.\n\nSize & Fit: Order your regular shoe size.\n\nSpecs: Approx. weight: 1 lb. 8 oz.\n\nConstruction:\n- New upper and panel mesh are softer and more breathable. \n- Nubuck leather upper with abrasion-resistant synthetic panels. \n- 3D molded heel counter helps shoes maintain a snug, comfortable heel hold over time. \n- Dual-density EVA midsole provides supportive balanced cushioning. \n- Nylon shank offers added support between heel and forefoot. \n- Classic Oboz Sawtooth sole sheds mud and provides exceptional traction. \n- Sidewall lugs grip off-camber trails while shaving weight. \n- Low-density EVA pods provide cushioning and comfort. \n- Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 45}),
#  Document(page_content=': 46\nname: Kids\' OluKai Nohea Breeze Slip-Ons\ndescription: With its handsewn seam stitching, comfy fit and easy-going style, these Hawaiian-inspired kids\' OluKai slip-ons are sure to be instant favorites from the get-go. Constructed with lightweight, durable cotton canvas upper, with soft microfiber lining, the shoes feature elastic goring for easy on/off, an anatomical compression-molded EVA footbed with arch and heel contour for all-day support, and a rubber cupsole for year-round conditions. The all-weather rubber outsole has heavy gauge sidewall stitching and molded rubber pods for traction. Additional features include a versatile Drop-in Heel® that lets kids wear them as a shoe or a slide, a removable and washable footbed, and embroidered logo detailing. Imported. "Nohea Lole" translates to "handsome/lovely."', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 46}),
#  Document(page_content=": 47\nname: Angler's Athletic Shorts\ndescription: These high-performance fly-fishing shorts are also great for all-around wear. They're made with super-comfortable, durable materials with built-in technical fishing features.\n\nSize & Fit\nStandard Fit: Sits lower on the waist and straight through the hip and thigh for a streamlined look.\n\nFabric & Care\n90% nylon, 10% spandex. UPF 50+ rated – the highest rated sun protection possible. Machine wash cold with like colors, tumble dry low.\n\nConstruction\nQuick-drying lightweight synthetic fabric with four-way stretch for comfort and performance. Articulation provides active range of motion.\n\nAdditional Features\nTwo front slash pockets with nylon web reinforcements for knife/tool clip. Nylon web belt loops are low profile and rugged. Right-rear and left-front-thigh zippered security pockets for wallet, phone or other essentials. Center front button is secure and extremely durable. Imported.\n\nSun Protection That Won't Wear Off \nOur high-performance fabric provides SPF 50+ sun protection, blocking 98% of the sun's harmful rays.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 47}),
#  Document(page_content=': 48\nname: Print Flannel Trousers\ndescription: Welcome crisp fall nights with cozy flannel pajama pants, complete with pockets and an easy-on drawstring waist. Size & Fit Classic Fit: Sits at the waist. Inseam: 30". Petite 28". Fabric & Care 100% cotton flannel, brushed for extra softness. Machine wash and dry. Imported. Questions? Contact our customer service team for further assistance.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 48}),
#  Document(page_content=': 49\nname: Premium Double L Short-Sleeve Polo Banded Without Pocket\ndescription: This extraordinary all-cotton polo simply will not wrinkle, fade, shrink or pill. Size & Fit - Traditional Fit: Relaxed through the chest, sleeve and waist. Why We Love It - We’ve updated the fit of our most popular polo, with trimmer, shorter sleeves that sit higher on the shoulders. It will look and feel great for years to come. Fabric & Care - Super-soft cotton pique-knit allows air to circulate. Machine wash and dry. Additional Features - Printed label for added comfort. Imported. \n\n for Business - Your Logo. Our Quality. SAVE UP TO 20% WITH VOLUME DISCOUNTS - Add your logo to this product for business outfitting, gear and gifts.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 49}),
#  Document(page_content=': 50\nname: CamelBak Chute Mag Elite Water Bottle, 12 oz.\ndescription: This new-and-improved Chute water bottle features a magnetic top that easily stows the cap while you\'re drinking. 100% leakproof, it\'s a great choice for staying hydrated during all your outdoor adventures. \n\nSpecs \n- Capacity: 12 oz. \n- Height: 7.9" \n- Weight: 4.5 oz. \n\nConstruction \n- BPA-, BPS- and BPF-free. \n- Made from Tritan copolyester. \n- Cap is made from polypropylene. \n\nAdditional Features \n- Magnetic handle keeps cap stowed while drinking. \n- 100% leakproof design. \n- Ergonomic high-flow spout. \n- Comfortable carry handle. \n- All parts are top rack dishwasher safe. \n- Fits most car cup holders. \n- Imported.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 50}),
#  Document(page_content=": 51\nname: Mountain Peak Polarized Sunglasses\ndescription: The Native Catamount features a semi-rimless, vented frame that's ideal for cycling, Nordic skiing, mountain biking and other high-energy pursuits. Interchangable lenses allow you to adapt these polarized sunglasses to changing light conditions. Construction includes lenses that selectively filter UV for higher contrast and crisp definition, blocking up to four times more infrared light than standard lenses. The frames are made of Rhyno-Tuff AIR, a light and durable material, with Cushinol nose and temple pads to prevent slipping, cam-action hinges for durability and crisp opening, and a tri-laminate frame construction that improves durability. The Mastoid Temple Grip helps keep frames in place and the Advanced polarized N3 polycarbonate lenses are extremely durable. Frames are also made from biodegradable caster resin instead of petroleum-based products. Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 51}),
# ...
#  Document(page_content=': 731\nname: Flexible Performance Shorts, 8"\ndescription: Our most versatile swim trunks are perfect for swimming, running, kayaking or any unexpected adventure. Redesigned to be more comfortable and better looking than ever, they feature an 8" inseam and a classic fit that sits at the natural waist and trim, with a traditional straight leg. Made with lightweight, breathable 100% nylon fabric and UPF 50+ rated sun protection, these trunks also boast a super soft, quick-drying, anti-odor polyester mesh liner. The updated elastic waistband has an internal adjustable drawstring for just the right fit and the three-ply Supplex fabric is lightweight, breathable and brushed for softness. In addition, these trunks have a durable water-repellent finish and include side seam pocket and back welt pocket with velcro closure both with mesh drainage panels and our iconic Mt.Katahdin logo on the lower left leg. Rinse thoroughly after use and machine wash and dry for best results. Imported.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 731}),
#  Document(page_content=": 732\nname: Men's Ventilated Keen Targhee Trekking Shoes\ndescription: Tackle the trail with confidence in these Keen Targhee Ventilated Hiking Shoes. They feature excellent traction with grippy rubber outsoles and a heel-capture system that promotes stability with every step.\n\nSize & Fit\nRecommend ordering one half size larger than regular shoe size or your regular Keen size. Sizes 12½, order size 13.\n\nSpecs\nApprox. weight: 1 lb. 13.6 oz. per pair.\n\nConstruction\nLightweight nubuck leather upper.\nRemovable metatomical dual-density EVA footbeds cushion your stride.\nInjected thermoplastic urethane heel-capture system promotes stability as you hike.\nReinforced eyelets are durable and allow easy adjustment.\nKEEN all-terrain nonmarking rubber outsoles provide reliable traction.\nBreathable mesh lining wicks moisture away from your feet.\nDual-density compression-molded EVA foam midsole.\nImported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 732}),
#  Document(page_content=': 733\nname: Voyager Outdoor Lamp\ndescription: The Traverse Cube Outdoor Light is an extremely versatile and great camp lantern for all ages. With up to 200 lumens on high power and 56 lumens on low power, it provides plenty of light for nighttime activities like card games or just illuminating a tent. It also has a special mode that cycles through the colors of the rainbow, making it perfect for kids. This light is constructed from a silicone globe and impact-resistant ABS plastic base, making it water-resistant and able to float if dropped in the water. Plus, it has a convenient handle for carrying or hanging at your campsite. With a weight of 7.7 oz. with batteries and dimensions of 4.5"H x 3.25"W x 3.25"D, it is sure to be a fun and practical addition to your camping gear. Batteries are not included. With up to 14 days of run time on low power, this light is perfect for long camping trips.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 733}),
#  Document(page_content=': 734\nname: Therma-Fur Insoles\ndescription: Enhance the fit and performance of your favorite foul-weather boots with these men’s shearling insoles—and keep moisture and odor at bay.\n\nSize & Fit\nFor Men, order your regular shoe size, half sizes order up. For Women, please consult the size chart before ordering to ensure the correct fit.\n\nFabric & Care\nHandwash, line dry.\n\nConstruction\nMade from dyed and treated lamb shearling. Bottom is constructed with EVA foam for comfort, cushioning and support. \n\nAdditional Features\nRegulates foot temperature while wicking moisture to control odors. Imported (fur Australia).', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 734}),
#  Document(page_content=': 735\nname: CozyWool Midweight Performance T-Zip, Print\ndescription: This 250-weight quarter-zip top is made of merino wool to naturally wick away sweat, resist odor and keep you warm in a wide range of activities and temperatures. Our exclusive wool performance fabric provides an ideal base layer for cool-weather sports, with fine merino-wool fibers to speed moisture away from your body and trap heat for warmth and comfort. The fabric is made of itch-free 100% merino wool, machine washable in cold water with like colors and can be tumble dried low. It features a fine-gauge knit with flatlock seams for a remarkably soft, smooth fit, thumbhole cuffs to keep sleeves snug at wrist, and a quarter-zip for ventilation. It is a midweight layer, naturally resisting odors for the lifetime of the fabric. Imported.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 735}),
#  Document(page_content=": 736\nname: Boys' Athletic Performance Tee\ndescription: Take his game to the next level with our quick-drying, moisture-wicking boys' fitness T-shirt. It has all the features he needs, plus an odor-fighting fabric that stays fresh all day. A great all-around performance tee – at a great price. \n\nSize & Fit: Slightly Fitted. \n\nFabric & Care: 100% polyester. Machine wash and dry. \n\nAdditional Features: Dries quickly and wicks away moisture to keep him cool and dry. Antimicrobial fabric controls odors. Reflective logo on chest increases visibility. Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 736}),
#  Document(page_content=": 737\nname: Plush Plaid Scarf\ndescription: The oversized plaid scarf is the perfect addition to your wardrobe. It can be draped beautifully over your shoulders or wrapped around your neck multiple times. Crafted from 100% wool, this scarf is wonderfully soft to the touch. Be sure to handwash and dry flat for best results. It also features a fringed edge, making it extra special. Imported. If you have any questions, please don't hesitate to ask.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 737}),
#  Document(page_content=': 738\nname: Solshine Polarized Sunglasses\ndescription: Stylish, lightweight and comfortable, Suncloud Scene polarized sunglasses will protect your eyes during all your time outside. Construction: Lenses provide 100% UV protection, and polarized lenses cut glare on water and roads. Tough, lightweight Grilamid nylon frames and polycarbonate lenses are scratch and impact resistant. Additional Features: Fit small faces best. Imported. Have any questions? Feel free to reach out to customer service.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 738}),
#  Document(page_content=': 739\nname: Rustic 6\' Wood Entertainment Stand\ndescription: Experience rustic style in your entertainment center with our console. Handcrafted from white pine and finished by hand, this console features a 72" width to accommodate larger TVs. This console is made from rough-sawn white pine, finished with a durable low-sheen topcoat and plywood back. No two pieces are exactly alike and each arrives fully assembled. Made in the USA, this console measures 30"H x 72"W x 15"D, and weighs approx. 75 lb.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 739}),
#  Document(page_content=': 740\nname: Traveler Pro Duffle Bag\ndescription: This ultra-packable, superlight duffle packs down into its own pocket for convenient storage. It\'s a great choice for carrying gear, travel or for your next trip to the gym. It weighs in at an amazing 8.3 ounces. \n\nSpecs: \n- Capacity: 1,830 cu. in., 30 L.\n- Weight: 8.3 oz.\n- Open Dimensions: 19.5"L x 8"W x 10.5"D.\n- Packed Dimensions: 8" x 7".\n\nConstruction:\n- Made from rugged 70D nylon ripstop.\n- Stow pocket for compact storage.\n- Reinforced bottom features 3 mm of foam for extra durability.\n- Cord-reinforced handle for secure carrying.\n- Haul loops on each end.\n- Top compression straps over zippers stabilize the load and add durability.\n- Zippered  mesh pocket with key fob on back.\n- Lash points in all four corners.\n- Imported.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 740}),
#  Document(page_content=': 741\nname: Signature Summer Plaid Popover Shirt, Short-Sleeve Indigo Madras\ndescription: This lightweight popover features true indigo dyes, giving a new dimension to the cotton madras. Rich blue hues create a refreshingly new look, in a slim pullover style. It is exceptionally soft and breathable, making it perfect for summer days.\n\nSize & Fit: Slim Fit: Cut slim through the chest, sleeve and waist.\n\nFabric & Care: 100% cotton. Machine wash and dry.\n\nAdditional Features: Spread collar, Three-button placket, Single chest pocket, Chambray trim details. Imported.\n\nQuestions? Please contact us for more information.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 741}),
#  Document(page_content=": 742\nname: Children's  Boots, Insulated\ndescription: The original  Boot, handcrafted in Maine since 1912 – in sizes just for kids. Lined with Thinsulate Insulation to keep their toes toasty. \n\nSize & Fit: Whole sizes, order 1 size down. Half sizes, order 1½ sizes down. \n\nWhy We Love Them: Our children's duck boots feature the same impeccable construction as our adult styles, combining the waterproof protection of rubber-bottom boots with the comfort of full-grain leather. Made right here in Maine by expert craftspeople who treat each pair like it was made for their own kids. \n\nVideo: One Minute on  Boot Care \n\nConstruction: Full-grain leather upper and rubber chain-link tread. Moisture-wicking liner. 3M™ Thinsulate™ Insulation in footbed helps keep feet warm and dry. \n\nAdditional Features: Proven to shed rain and snow. Uniquely shaped foot form offers the stability and comfort kids need. USA. \n\nQuestions? Please contact us for any inquiries.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 742}),
#  Document(page_content=": 743\nname: Heritage Rugby, Traditional Fit Long-Sleeve Shoulder Stripe\ndescription: This engineer-striped rugby shirt is an authentic classic with rubber buttons and a rugged all-cotton fabric. It's lighter than our original rugby, but still has the same familiar feel. The traditional fit is relaxed through the chest, sleeve and waist, and it's washed for the appearance of being worn for years. Crafted with a woven collar, rubber buttons, herringbone-taped double placket, ribbed cuffs and a droptail hem, this timeless piece is finished with chambray trim at the collar, label and side vents. Machine wash and dry for easy care. Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 743}),
#  Document(page_content=': 744\nname: Wayfarer Lantern\ndescription: This bright camping lantern is lightweight and compact enough take with you on backcountry adventures. With folding legs and a collapsible dome, it won\'t take up much space in your pack. \n\nSpecs\nOpen height: 5".\nCollapsed height: 2.5".\nWeight: 5.5 oz.\n\nAdditional Features\nPuts out up to 150 lumens of light, dimmable to 30.\nRemovable globe lets you use it as a hanging tent light or as a flashlight.\nBuilt-in hook in each leg provide multiple hanging options.\nDimmable green LED for preserving night vision.\nRuns up to 32 hours on three AAA batteries, included.\nImported.\nQuestions?  Please contact customer service for help.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 744}),
#  Document(page_content=": 745\nname: SnuggleSweats Pullover\ndescription: Made from soft performance fabric, this cowl-neck sweatshirt is incredibly comfortable and cozy. It's soft to the touch and only gets cozier with time. Plus, it wicks moisture and moves with you for on-the-go comfort. Its slightly fitted shape softly shapes the body and falls at low hip. It has an oversized adjustable cowlneck, kangaroo pocket, tall rib-knit cuffs and thumbholes to keep sleeves in place. This sweatshirt is machine washable and dryable and is imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 745}),
#  Document(page_content=': 746\nname: Women\'s Keen Targhee III Waterproof Mid-Hikers\ndescription: The Targhee mid hiker is a lean, tough and gritty hiking shoe that packs modern design and performance materials into one stylish package.\n\nSize & Fit\n\nThis shoe fits short in length; we recommend ordering ½ size larger than your regular shoe size or your regular Keen size. Size 10 & 10½ wearers should order size 11.\n\nSpecs\n\nApprox. weight: 1 lb. 14 oz. per pair\nHeight: 4½"\n\nConstruction\n\nThis shoe is waterproof and constructed with leather and performance mesh upper. It is also equipped with Keen.Dry waterproof barrier to keep water out while allowing vapor to escape. The moisture-wicking synthetic liner is treated for odor control. Dual-density compression-molded EVA midsole and removable EVA foam footbed offer cushioning. It features Keen all-terrain rubber outsole for high traction grip, and Keen\'s "S3" internal heel support structure for torsion control.\n\nAdditional Features\n\nThis shoe also comes with ESS shank for lightweight support, midcut height for ankle support, web pull-on loops at back collar and tongue, and web tab lacing system to draw heel inward to hold foot securely.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 746}),
#  Document(page_content=': 747\nname: Midweight Cotton Slub Rollneck Striped Sweater\ndescription: Softly textured in cotton slub yarns, this striped pullover sweater will keep you cool and comfortable throughout the warmer months. \n\nSize & Fit: \nSlightly Fitted: Softly shapes the body. Falls at hip.\n\nFabric & Care: \n100% cotton. Machine wash, dry flat. \n\nAdditional Features:\nRoll neck detail. Rib-trimmed cuffs and hem. Imported. \n\nQuestions? Contact our Customer Service team for further assistance.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 747}),
#  Document(page_content=": 748\nname: Traveler's Quilted Vest.\ndescription: Fantastically fun and functional, this camo vest conveniently packs into its own pocket. Slim and stylish, thanks to PrimaLoft® insulation, it makes a great extra layer in colder weather and can be the only layer you'll need when spring arrives.\n\nSize & Fit\nSlightly Fitted: Softly shapes the body.\nFalls at high hip.\n\nWhy We Love It\nToss this lightweight quilted vest in your tote or handbag, then unzip and wear when you need an extra layer. Stuff it back in its pocket and zip when you’re all set.\n\nFabric & Care\nWater-resistant shell is made from 100% nylon ripstop.\n100% nylon lining.\n100-gram PrimaLoft polyester insulation.\nMachine wash and dry.\n\nAdditional Features\nRibbed trim at neck.\nInterior zipper.\nPacks away into its own back zippered pocket.\nCustom logo hardware.\nImported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 748}),
#  Document(page_content=": 749\nname: Women's Emerge Wading Jacket\ndescription: Not just a man's jacket made smaller, this wading jacket is designed to fit a woman's body. Fabric & Care: 100% nylon. Machine wash cold with like colors, tumble dry low. Additional Features: Field-tested by women fly fishers to ensure it fits right. Two vertical chest pockets near the front zipper hold small fly boxes and tools. Two large handwarmer pockets that can also carry two large fly boxes. The superlight fabric is very breathable yet still dependably waterproof. Gusseted cuffs keep water out when releasing fish or casting in the rain. Hood adjusts with a cord-lock in back. All closures have a low-profile design to minimize line catching. Imported.", metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 749})]

# %%
len(docs_750)

# %%
# Create embeddings for all pieces of text just loaded and store them in a vectore store
# using the `from_documents` method on the vector stor
db = DocArrayInMemorySearch.from_documents(
    docs_750,  # docs has 1000 element which require more than 150000 TPM (tohen per minute)
    # In free trial mode, the token limits for `text-embedding-3-small` model is 150000 TPM
    embeddings
)

# %%
query = "Please suggest a shirt with sunblocking"

# %%
docs_750 = db.similarity_search(query)

# %%
len(docs_750)
# Out:
# 4

# %%
docs_750[0]
# Out:
# Document(page_content=': 255\nname: Sun Shield Shirt by\ndescription: "Block the sun, not the fun – our high-performance sun shirt is guaranteed to protect from harmful UV rays. \n\nSize & Fit: Slightly Fitted: Softly shapes the body. Falls at hip.\n\nFabric & Care: 78% nylon, 22% Lycra Xtra Life fiber. UPF 50+ rated – the highest rated sun protection possible. Handwash, line dry.\n\nAdditional Features: Wicks moisture for quick-drying comfort. Fits comfortably over your favorite swimsuit. Abrasion resistant for season after season of wear. Imported.\n\nSun Protection That Won\'t Wear Off\nOur high-performance fabric provides SPF 50+ sun protection, blocking 98% of the sun\'s harmful rays. This fabric is recommended by The Skin Cancer Foundation as an effective UV protectant.', metadata={'source': 'l4_outdoor_clothing_catalog_1000.csv', 'row': 255})

# %%
# Create a retriever
retriever = db.as_retriever()

# %%
# LLM model
llm = ChatOpenAI(temperature=0.0)

# %%
qdocs = "".join([docs[i].page_content for i in range(len(docs_750))])

# %%
response = llm.call_as_llm(f"{qdocs} Question: Please list all your shirts with sun \
protection in a table in markdown and summarize each one.") 

# call_as_llm is deprecated, use invoke
# response = llm.invoke(f"{qdocs} Question: Please list all your shirts with sun \
# protection in a table in markdown and summarize each one.")
# Out:
# /home/hassane/anaconda3/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `call_as_llm` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(

# %%
display(Markdown(response))
# Out:
# | Name                                    | Summary                                                                                                                                                                                                                   |
# |-----------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Refresh Swimwear, V-Neck Tankini Contrasts | This tankini top is designed for watersports, made with recycled nylon and Lycra spandex for stretch. It offers UPF 50+ sun protection and features racerback straps for easy wear. |
# | Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece | A toddler's two-piece swimsuit with bright colors, ruffles, and exclusive prints. Made with four-way-stretch, chlorine-resistant fabric and UPF 50+ sun protection. |
# | Women's Campside Oxfords                | Comfortable lace-to-toe Oxford shoes made of soft canvas with cushioning and support. Features antimicrobial odor control and a vintage motif on the innersole.          |
# | Recycled Waterhog Dog Mat, Chevron Weave | An ultradurable dog mat made from recycled materials, designed to keep dirt and water off floors. Features thick and thin fibers for dirt absorption and water retention.   |

# %%
qa_stuff = RetrievalQA.from_chain_type(
    llm=llm, 
    chain_type="stuff", 
    retriever=retriever, 
    verbose=True
)

# %%
query =  "Please list all your shirts with sun protection in a table in markdown and summarize each one."

# %%
response = qa_stuff.run(query)
# response = qa_stuff.invoke(query)
# Out:
# /home/hassane/anaconda3/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# > Entering new RetrievalQA chain...
# > Finished chain.

# %%
len(response)

# %%
display(Markdown(response))
# Out:
# | Shirt Name                                | Description

# %%
response = index.query(query, llm=llm)

# %%
index = VectorstoreIndexCreator(
    vectorstore_cls=DocArrayInMemorySearch,
    embedding=embeddings,
).from_loaders([loader])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[36], line 4
#       1 index = VectorstoreIndexCreator(
#       2     vectorstore_cls=DocArrayInMemorySearch,
#       3     embedding=embeddings,
# ----> 4 ).from_loaders([loader])
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/indexes/vectorstore.py:83, in VectorstoreIndexCreator.from_loaders(self, loaders)
#      81 for loader in loaders:
#      82     docs.extend(loader.load())
# ---> 83 return self.from_documents(docs)
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/indexes/vectorstore.py:88, in VectorstoreIndexCreator.from_documents(self, documents)
#      86 """Create a vectorstore index from documents."""
#      87 sub_docs = self.text_splitter.split_documents(documents)
# ---> 88 vectorstore = self.vectorstore_cls.from_documents(
#      89     sub_docs, self.embedding, **self.vectorstore_kwargs
#      90 )
#      91 return VectorStoreIndexWrapper(vectorstore=vectorstore)
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_core/vectorstores.py:528, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     526 texts = [d.page_content for d in documents]
#     527 metadatas = [d.metadata for d in documents]
# --> 528 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_community/vectorstores/docarray/in_memory.py:69, in DocArrayInMemorySearch.from_texts(cls, texts, embedding, metadatas, **kwargs)
#      54 """Create an DocArrayInMemorySearch store and insert data.
#      55
#      56 Args:
#    (...)
#      66     DocArrayInMemorySearch Vector Store
#      67 """
#      68 store = cls.from_params(embedding, **kwargs)
# ---> 69 store.add_texts(texts=texts, metadatas=metadatas)
#      70 return store
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_community/vectorstores/docarray/base.py:82, in DocArrayIndex.add_texts(self, texts, metadatas, **kwargs)
#      72 """Embed texts and add to the vector store.
#      73
#      74 Args:
#    (...)
#      79     List of ids from adding the texts into the vectorstore.
#      80 """
#      81 ids: List[str] = []
# ---> 82 embeddings = self.embedding.embed_documents(list(texts))
#      83 for i, (t, e) in enumerate(zip(texts, embeddings)):
#      84     m = metadatas[i] if metadatas else {}
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_openai/embeddings/base.py:508, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     505 # NOTE: to keep things simple, we assume the list may contain texts longer
#     506 #       than the maximum context and use length-safe embedding function.
#     507 engine = cast(str, self.deployment)
# --> 508 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_openai/embeddings/base.py:324, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     322 batched_embeddings: List[List[float]] = []
#     323 for i in _iter:
# --> 324     response = self.client.create(
#     325         input=tokens[i : i + _chunk_size], **self._invocation_params
#     326     )
#     327     if not isinstance(response, dict):
#     328         response = response.model_dump()
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/resources/embeddings.py:113, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     107         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     108             base64.b64decode(data), dtype="float32"
#     109         ).tolist()
#     111     return obj
# --> 113 return self._post(
#     114     "/embeddings",
#     115     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     116     options=make_request_options(
#     117         extra_headers=extra_headers,
#     118         extra_query=extra_query,
#     119         extra_body=extra_body,
#     120         timeout=timeout,
#     121         post_parser=parser,
#     122     ),
#     123     cast_to=CreateEmbeddingResponse,
#     124 )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1200, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1186 def post(
#    1187     self,
#    1188     path: str,
#    (...)
#    1195     stream_cls: type[_StreamT] | None = None,
#    1196 ) -> ResponseT | _StreamT:
#    1197     opts = FinalRequestOptions.construct(
#    1198         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1199     )
# -> 1200     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:889, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     880 def request(
#     881     self,
#     882     cast_to: Type[ResponseT],
#    (...)
#     887     stream_cls: type[_StreamT] | None = None,
#     888 ) -> ResponseT | _StreamT:
# --> 889     return self._request(
#     890         cast_to=cast_to,
#     891         options=options,
#     892         stream=stream,
#     893         stream_cls=stream_cls,
#     894         remaining_retries=remaining_retries,
#     895     )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:965, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     963 if retries > 0 and self._should_retry(err.response):
#     964     err.response.close()
# --> 965     return self._retry_request(
#     966         options,
#     967         cast_to,
#     968         retries,
#     969         err.response.headers,
#     970         stream=stream,
#     971         stream_cls=stream_cls,
#     972     )
#     974 # If the response is streamed then we need to explicitly read the response
#     975 # to completion before attempting to access the response text.
#     976 if not err.response.is_closed:
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1013, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1009 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1010 # different thread if necessary.
#    1011 time.sleep(timeout)
# -> 1013 return self._request(
#    1014     options=options,
#    1015     cast_to=cast_to,
#    1016     remaining_retries=remaining,
#    1017     stream=stream,
#    1018     stream_cls=stream_cls,
#    1019 )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:965, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     963 if retries > 0 and self._should_retry(err.response):
#     964     err.response.close()
# --> 965     return self._retry_request(
#     966         options,
#     967         cast_to,
#     968         retries,
#     969         err.response.headers,
#     970         stream=stream,
#     971         stream_cls=stream_cls,
#     972     )
#     974 # If the response is streamed then we need to explicitly read the response
#     975 # to completion before attempting to access the response text.
#     976 if not err.response.is_closed:
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1013, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1009 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1010 # different thread if necessary.
#    1011 time.sleep(timeout)
# -> 1013 return self._request(
#    1014     options=options,
#    1015     cast_to=cast_to,
#    1016     remaining_retries=remaining,
#    1017     stream=stream,
#    1018     stream_cls=stream_cls,
#    1019 )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:980, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     977         err.response.read()
#     979     log.debug("Re-raising status error")
# --> 980     raise self._make_status_error_from_response(err.response) from None
#     982 return self._process_response(
#     983     cast_to=cast_to,
#     984     options=options,
#    (...)
#     987     stream_cls=stream_cls,
#     988 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for text-embedding-ada-002 in organization org-OQAm0D5NGQg76QasCmf9Cfrn on requests per min (RPM): Limit 3, Used 3, Requested 1. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
